# %%
#爬取Dcard內容
import urllib.request as req
import bs4 
s="https://www.dcard.tw/f"
s1=req.Request(s,headers={
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"
})
with req.urlopen(s1) as response:
    da=response.read().decode("utf-8")
soup=bs4.BeautifulSoup(da,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
#Request 取回之後該怎麼取出資料，資料型態是什麼？
#用BeautifulSoup解析HTML，資料型態為字串String

# %%
#為什麼要使用 BeatifulSoup 處理？
#可以用來解析HTML、XML文件，亦可以用標籤取得資料，非常方便

# %%
#爬取知乎內容
s="https://www.zhihu.com/explore"
s1=req.Request(s,headers={
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"
})
with req.urlopen(s1) as response:
    data=response.read().decode("utf-8")
soup=bs4.BeautifulSoup(data,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# ...
